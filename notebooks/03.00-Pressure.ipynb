# %% [markdown]
# <!--NOTEBOOK_HEADER-->
# *This notebook contains course material from [FAT0413156](https://gmxavier.github.io/FAT0413156)
# by Gilberto Xavier (gmxavier at fat.uerj.br); the content is available [on Github](https://github.com/gmxavier/FAT0413156.git).
# The text is released under the [CC-BY-NC-SA-4.0 license](https://creativecommons.org/licenses/by-nc-sa/4.0/legalcode),
# and code is released under the [MIT license](https://opensource.org/licenses/MIT).*

# %% [markdown]
# <!--NAVIGATION-->
# < [Introduction](http://nbviewer.jupyter.org/github/gmxavier/FAT0413156/blob/master/notebooks/02.00-Introduction.ipynb) | [Contents](toc.ipynb) | [Level measurement](http://nbviewer.jupyter.org/github/gmxavier/FAT0413156/blob/master/notebooks/04.00-Level.ipynb) ><p><a href="https://colab.research.google.com/github/gmxavier/FAT0413156/blob/master/notebooks/03.00-Pressure.ipynb" target="_parent"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a><p><a href="https://raw.githubusercontent.com/gmxavier/FAT0413156/master/notebooks/03.00-Pressure.ipynb" target="_parent"><img align="left" src="https://img.shields.io/badge/Github-Download-blue.svg" alt="Download" title="Download Notebook"></a>

# %% [markdown]
# # Pressure measurement

# %% [markdown]
# ## Continuous pressure measurement ([Lessons in Industrial Instrumentation, Chapter 19](https://www.ibiblio.org/kuphaldt/socratic/sinst/book/liii.pdf#page=1338))
#
# Supplementary material:
# - [Pressure measurement on Wikipedia](https://en.wikipedia.org/wiki/Pressure_measurement)

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('kt-MxC3_1o')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/kt-MxC3_1o"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
YouTubeVideo('iru8tRwS7Yc')

# %% [markdown]
# ### Manometers ([Lessons in Industrial Instrumentation, Section 19.1](https://www.ibiblio.org/kuphaldt/socratic/sinst/book/liii.pdf#page=1339))

# %%
YouTubeVideo('gxrkLkJybnA')

# %% [markdown]
# ### Mechanical pressure elements ([Lessons in Industrial Instrumentation, Section 19.2](https://www.ibiblio.org/kuphaldt/socratic/sinst/book/liii.pdf#page=1345))

# %%
YouTubeVideo('f9MJAXhLSv0')

# %%
YouTubeVideo('IxhNLtP8jpI')

# %%
YouTubeVideo('ILTgNUow3i4')

# %% [markdown]
# ### Electrical pressure elements ([Lessons in Industrial Instrumentation, Section 19.3](https://www.ibiblio.org/kuphaldt/socratic/sinst/book/liii.pdf#page=1351))

# %%
YouTubeVideo('HrXNZWDktYA')

# %% [markdown]
# ### Force-balance pressure transmitters ([Lessons in Industrial Instrumentation, Section 19.4](https://www.ibiblio.org/kuphaldt/socratic/sinst/book/liii.pdf#page=1369))

# %% [markdown]
# ### Differential pressure transmitters ([Lessons in Industrial Instrumentation, Section 19.5](https://www.ibiblio.org/kuphaldt/socratic/sinst/book/liii.pdf#page=1372))

# %%
YouTubeVideo('XkMEto_x22A')

# %% [markdown]
# ### Pressure sensor accessories ([Lessons in Industrial Instrumentation, Section 19.6](https://www.ibiblio.org/kuphaldt/socratic/sinst/book/liii.pdf#page=1389))

# %% [markdown]
# ## Discrete pressure measurement ([Lessons in Industrial Instrumentation,  Section 9.5](https://www.ibiblio.org/kuphaldt/socratic/sinst/book/liii.pdf#page=697))

# %%
YouTubeVideo('1VdSxSRhadM')

# %% [markdown]
# ## Exercises
#
# Try to solve the problems listed [here](https://doc.lagout.org/electronics/Fundamentals%20of%20Industrial%20Instrumentation%20and%20Process%20Control%20%5Bby%20William%20Dunn%5D.pdf) on page 82.
#
# Tip: Take a look [here](https://www.ibiblio.org/kuphaldt/socratic/sinst/book/liii.pdf#page=87) to get some conversion factors.

# %% [markdown]
# <!--NAVIGATION-->
# < [Introduction](http://nbviewer.jupyter.org/github/gmxavier/FAT0413156/blob/master/notebooks/02.00-Introduction.ipynb) | [Contents](toc.ipynb) | [Level measurement](http://nbviewer.jupyter.org/github/gmxavier/FAT0413156/blob/master/notebooks/04.00-Level.ipynb) ><p><a href="https://colab.research.google.com/github/gmxavier/FAT0413156/blob/master/notebooks/03.00-Pressure.ipynb" target="_parent"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a><p><a href="https://raw.githubusercontent.com/gmxavier/FAT0413156/master/notebooks/03.00-Pressure.ipynb" target="_parent"><img align="left" src="https://img.shields.io/badge/Github-Download-blue.svg" alt="Download" title="Download Notebook"></a>
